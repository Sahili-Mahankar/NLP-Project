# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('job_dataset.csv')

# %%
df
# Out:
#        job_id         job_title             company              location  \
# 0   JOB809570    Java Developer                 IBM   Nagpur, Maharashtra
# 1   JOB731262       AI Engineer             Infosys     Pune, Maharashtra
# 2   JOB106814      Data Analyst       Tech Mahindra  Noida, Uttar Pradesh
# 3   JOB452944      NLP Engineer  Persistent Systems  Bengaluru, Karnataka
# 4   JOB865179  Business Analyst             HCLTech  Hyderabad, Telangana
# ..        ...               ...                 ...                   ...
# 95  JOB335729  Business Analyst   Fractal Analytics    Ahmedabad, Gujarat
# 96  JOB723948    Java Developer           Accenture   Mumbai, Maharashtra
# 97  JOB624783       AI Engineer             HCLTech  Noida, Uttar Pradesh
# 98  JOB733039     SQL Developer               Wipro     Gurugram, Haryana
# 99  JOB804938     Data Engineer       Tech Mahindra    Ahmedabad, Gujarat
#
#                                       job_description  experience  \
# 0   We are hiring a Java Developer at IBM in Nagpu...   0-1 years
# 1   We are hiring a AI Engineer at Infosys in Pune...   5-8 years
# 2   We are hiring a Data Analyst at Tech Mahindra ...   0-1 years
# 3   We are hiring a NLP Engineer at Persistent Sys...   5-8 years
# 4   We are hiring a Business Analyst at HCLTech in...   5-8 years
# ..                                                ...         ...
# 95  We are hiring a Business Analyst at Fractal An...   3-6 years
# 96  We are hiring a Java Developer at Accenture in...   2-5 years
# 97  We are hiring a AI Engineer at HCLTech in Noid...   2-5 years
# 98  We are hiring a SQL Developer at Wipro in Guru...  8-12 years
# 99  We are hiring a Data Engineer at Tech Mahindra...   1-3 years
#
#                   education  salary_lpa    job_type  \
# 0                       MCA         6.8   Part-time
# 1   BE Computer Engineering         6.8   Part-time
# 2    MTech Computer Science         7.2    Contract
# 3                       BCA        12.4   Part-time
# 4          BSc Data Science        11.2    Contract
# ..                      ...         ...         ...
# 95                      MCA         5.1  Internship
# 96   BTech Computer Science         9.3   Part-time
# 97     BSc Computer Science        10.4  Internship
# 98   BTech Computer Science        12.8  Internship
# 99   MTech Computer Science         9.4   Full-time
#
#                                       required_skills
# 0   Java, Spring Boot, Hibernate, Microservices, R...
# 1   Python, Machine Learning, Deep Learning, NLP, ...
# 2               SQL, Power BI, Excel, Tableau, Python
# 3   Python, NLP, BERT, Transformers, spaCy, NLTK, ...
# 4              SQL, Power BI, Excel, JIRA, Statistics
# ..                                                ...
# 95             SQL, Power BI, Excel, JIRA, Statistics
# 96  Java, Spring Boot, Hibernate, Microservices, R...
# 97  Python, TensorFlow, NLP, LLM, Docker, Deep Lea...
# 98  SQL Server, Python, MySQL, PostgreSQL, Databas...
# 99              Python, SQL, ETL, Spark, AWS, Airflow
#
# [100 rows x 10 columns]

# %%
df.head()
# Out:
#       job_id         job_title             company              location  \
# 0  JOB809570    Java Developer                 IBM   Nagpur, Maharashtra
# 1  JOB731262       AI Engineer             Infosys     Pune, Maharashtra
# 2  JOB106814      Data Analyst       Tech Mahindra  Noida, Uttar Pradesh
# 3  JOB452944      NLP Engineer  Persistent Systems  Bengaluru, Karnataka
# 4  JOB865179  Business Analyst             HCLTech  Hyderabad, Telangana
#
#                                      job_description experience  \
# 0  We are hiring a Java Developer at IBM in Nagpu...  0-1 years
# 1  We are hiring a AI Engineer at Infosys in Pune...  5-8 years
# 2  We are hiring a Data Analyst at Tech Mahindra ...  0-1 years
# 3  We are hiring a NLP Engineer at Persistent Sys...  5-8 years
# 4  We are hiring a Business Analyst at HCLTech in...  5-8 years
#
#                  education  salary_lpa   job_type  \
# 0                      MCA         6.8  Part-time
# 1  BE Computer Engineering         6.8  Part-time
# 2   MTech Computer Science         7.2   Contract
# 3                      BCA        12.4  Part-time
# 4         BSc Data Science        11.2   Contract
#
#                                      required_skills
# 0  Java, Spring Boot, Hibernate, Microservices, R...
# 1  Python, Machine Learning, Deep Learning, NLP, ...
# 2              SQL, Power BI, Excel, Tableau, Python
# 3  Python, NLP, BERT, Transformers, spaCy, NLTK, ...
# 4             SQL, Power BI, Excel, JIRA, Statistics

# %%
df.tail()
# Out:
#        job_id         job_title            company              location  \
# 95  JOB335729  Business Analyst  Fractal Analytics    Ahmedabad, Gujarat
# 96  JOB723948    Java Developer          Accenture   Mumbai, Maharashtra
# 97  JOB624783       AI Engineer            HCLTech  Noida, Uttar Pradesh
# 98  JOB733039     SQL Developer              Wipro     Gurugram, Haryana
# 99  JOB804938     Data Engineer      Tech Mahindra    Ahmedabad, Gujarat
#
#                                       job_description  experience  \
# 95  We are hiring a Business Analyst at Fractal An...   3-6 years
# 96  We are hiring a Java Developer at Accenture in...   2-5 years
# 97  We are hiring a AI Engineer at HCLTech in Noid...   2-5 years
# 98  We are hiring a SQL Developer at Wipro in Guru...  8-12 years
# 99  We are hiring a Data Engineer at Tech Mahindra...   1-3 years
#
#                  education  salary_lpa    job_type  \
# 95                     MCA         5.1  Internship
# 96  BTech Computer Science         9.3   Part-time
# 97    BSc Computer Science        10.4  Internship
# 98  BTech Computer Science        12.8  Internship
# 99  MTech Computer Science         9.4   Full-time
#
#                                       required_skills
# 95             SQL, Power BI, Excel, JIRA, Statistics
# 96  Java, Spring Boot, Hibernate, Microservices, R...
# 97  Python, TensorFlow, NLP, LLM, Docker, Deep Lea...
# 98  SQL Server, Python, MySQL, PostgreSQL, Databas...
# 99              Python, SQL, ETL, Spark, AWS, Airflow

# %%
df.sample(10)
# Out:
#        job_id         job_title        company              location  \
# 61  JOB345884   DevOps Engineer  Tech Mahindra  Bengaluru, Karnataka
# 46  JOB392683    Data Scientist        Mphasis  Hyderabad, Telangana
# 62  JOB827659     Data Engineer          Bosch   Mumbai, Maharashtra
# 60  JOB359249     Web Developer      Capgemini         Remote, India
# 82  JOB709805    Cloud Engineer       Deloitte   Nagpur, Maharashtra
# 32  JOB539589   DevOps Engineer        HCLTech     Gurugram, Haryana
# 63  JOB316881  Python Developer         Oracle   Chennai, Tamil Nadu
# 2   JOB106814      Data Analyst  Tech Mahindra  Noida, Uttar Pradesh
# 55  JOB254511     Web Developer  Tech Mahindra    Ahmedabad, Gujarat
# 10  JOB358607    Data Scientist         Amazon   Chennai, Tamil Nadu
#
#                                       job_description experience  \
# 61  We are hiring a DevOps Engineer at Tech Mahind...  5-8 years
# 46  We are hiring a Data Scientist at Mphasis in H...  1-3 years
# 62  We are hiring a Data Engineer at Bosch in Mumb...  5-8 years
# 60  We are hiring a Web Developer at Capgemini in ...  5-8 years
# 82  We are hiring a Cloud Engineer at Deloitte in ...  0-1 years
# 32  We are hiring a DevOps Engineer at HCLTech in ...  3-6 years
# 63  We are hiring a Python Developer at Oracle in ...  0-1 years
# 2   We are hiring a Data Analyst at Tech Mahindra ...  0-1 years
# 55  We are hiring a Web Developer at Tech Mahindra...  1-3 years
# 10  We are hiring a Data Scientist at Amazon in Ch...  1-3 years
#
#                  education  salary_lpa    job_type  \
# 61            Any Graduate        10.5   Full-time
# 46    BSc Computer Science         9.3   Full-time
# 62                     BCA         6.7   Part-time
# 60            Any Graduate         7.0  Internship
# 82        MSc Data Science         4.7   Part-time
# 32                     MCA         8.7   Full-time
# 63        BSc Data Science         5.3  Internship
# 2   MTech Computer Science         7.2    Contract
# 55    BSc Computer Science         8.3   Part-time
# 10            Any Graduate         5.1   Part-time
#
#                                       required_skills
# 61  AWS, Terraform, Docker, Kubernetes, Jenkins, C...
# 46  Python, Pandas, NumPy, Scikit-learn, Machine L...
# 62         Databricks, Azure, Spark, ETL, Python, SQL
# 60     React, Node.js, JavaScript, MongoDB, HTML, CSS
# 82  AWS, Azure, Docker, Kubernetes, Terraform, Lin...
# 32  Docker, Kubernetes, AWS, Jenkins, CI/CD, Linux...
# 63  Python, Django, Flask, FastAPI, SQL, Git, REST...
# 2               SQL, Power BI, Excel, Tableau, Python
# 55     React, Node.js, JavaScript, MongoDB, HTML, CSS
# 10  Python, TensorFlow, Statistics, Pandas, Machin...

# %%
df.shape
# Out:
# (100, 10)

# %%
df.columns
# Out:
# Index(['job_id', 'job_title', 'company', 'location', 'job_description',
#        'experience', 'education', 'salary_lpa', 'job_type', 'required_skills'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           100 non-null    object
#  1   job_title        100 non-null    object
#  2   company          100 non-null    object
#  3   location         100 non-null    object
#  4   job_description  100 non-null    object
#  5   experience       100 non-null    object
#  6   education        100 non-null    object
#  7   salary_lpa       100 non-null    float64
#  8   job_type         100 non-null    object
#  9   required_skills  100 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# job_id             0
# job_title          0
# company            0
# location           0
# job_description    0
# experience         0
# education          0
# salary_lpa         0
# job_type           0
# required_skills    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
